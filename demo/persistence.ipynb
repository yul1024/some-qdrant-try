# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

# %%
from langchain_ollama import OllamaEmbeddings

embedding_model = OllamaEmbeddings(model='nomic-embed-text:v1.5')

# %%
client = QdrantClient(path="./t_qdrant", check_compatibility=False)

# %%
client

# %%
client.create_collection(
    collection_name="demo",
    vectors_config=VectorParams(
        size=768,
        distance=Distance.COSINE,
    )
)
# Out:
# True

# %%
t_v = QdrantVectorStore.from_existing_collection(
    path="./t_qdrant",
    collection_name="demo",
    embedding=embedding_model,
)

# %%
t_v2 = QdrantVectorStore.from_existing_collection(
    path="./t_qdrant_2",
    collection_name="demo",
    embedding=embedding_model,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 t_v2 = QdrantVectorStore.from_existing_collection(
#       2     path="./t_qdrant_2",
#       3     collection_name="demo",
#       4     embedding=embedding_model,
#       5 )
#
# File ~\anaconda3\envs\smart_env\Lib\site-packages\langchain_qdrant\qdrant.py:480, in QdrantVectorStore.from_existing_collection(cls, collection_name, embedding, retrieval_mode, location, url, port, grpc_port, prefer_grpc, https, api_key, prefix, timeout, host, path, distance, content_payload_key, metadata_payload_key, vector_name, sparse_vector_name, sparse_embedding, validate_embeddings, validate_collection_config, **kwargs)
#     460 """Construct `QdrantVectorStore` from existing collection without adding data.
#     461
#     462 Returns:
#     463     QdrantVectorStore: A new instance of `QdrantVectorStore`.
# ...
